# %%
import pandas as pd

# %%
data = pd.read_csv("/Users/yaelinjo/GitHub/2020-Recosys-project/data/0220_prep.csv")

# %%
original = pd.read_csv("")

# %%
data.head()
# Out:
#                     UID                                           Full_URL  \
# 0  20120712210FAAE99B43  http://mw.cjmall.com/cjupload/cjmall/planshop/...
# 1  20120712210FAAE99B43  http://page.uplus.co.kr/index.html?v=MjAxMzEwM...
# 2  20120712210FAAE99B43                           http://page.uplus.co.kr/
# 3  20120712210FAAE99B43  http://page.uplus.co.kr/index.html?v=MjAxMzEwM...
# 4  20120712210FAAE99B43                                http://m.naver.com/
#
#         Domain                 Time ownership_1 ownership_2  PC  shop/product  \
# 0   cjmall.com  2014-06-01 14:07:26    Retailer         홈쇼핑   0             1
# 1  uplus.co.kr  2014-06-01 14:25:31       Maker     무선/이동통신   0             0
# 2  uplus.co.kr  2014-06-01 14:25:34       Maker     무선/이동통신   0             0
# 3  uplus.co.kr  2014-06-01 14:25:40       Maker     무선/이동통신   0             0
# 4    naver.com  2014-06-01 14:25:46      Portal         네이버   0             0
#
# ...
